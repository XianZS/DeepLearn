# %% [markdown]
# # softmax回归

# %%
import torch

# %% [markdown]
# ## 分类问题

# %% [markdown]
# 独热编码：独热编码是一个向量，它的分量和类别一样多。 类别对应的分量设置为1，其他所有分量设置为0。
#
# 假设存在三个a,b,c三个类别，那么他们的分量就是:
# - (1,0,0)
# - (0,1,0)
# - (0,0,1)
#
# ![image.png](attachment:0aadefd2-2247-49bc-9b11-81b929b57178.png)

# %%
# 为了估计所有可能类别的条件概率，我们需要一个有多个输出的模型，每个类别对应一个输出。 为了解决线性模型的分类问题，我们需要和输出一样多的仿射函数（affine function）。 每个输出对应于它自己的仿射函数。

# %% [markdown]
# ![image.png](attachment:92f65dbf-1347-45d2-bc4b-76db7eab4a7b.png)

# %% [markdown]
# ![image.png](attachment:ccceae12-67e3-471a-859d-336bba076590.png)

# %% [markdown]
# ![image.png](attachment:e8017921-7050-4711-9a9a-e70ad74479b1.png)

# %% [markdown]
# ![image.png](attachment:7684848c-2c70-45df-beba-797e8be5dc7e.png)
